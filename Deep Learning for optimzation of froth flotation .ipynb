# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('min.csv')

# %%
data.head()
# Out:
#                   date % Iron Feed % Silica Feed Starch Flow Amina Flow  \
# 0  2017-03-10 01:00:00        55,2         16,98     3019,53    557,434
# 1  2017-03-10 01:00:00        55,2         16,98     3024,41    563,965
# 2  2017-03-10 01:00:00        55,2         16,98     3043,46    568,054
# 3  2017-03-10 01:00:00        55,2         16,98     3047,36    568,665
# 4  2017-03-10 01:00:00        55,2         16,98     3033,69    558,167
#
#   Ore Pulp Flow Ore Pulp pH Ore Pulp Density Flotation Column 01 Air Flow  \
# 0       395,713     10,0664             1,74                      249,214
# 1       397,383     10,0672             1,74                      249,719
# 2       399,668      10,068             1,74                      249,741
# 3       397,939     10,0689             1,74                      249,917
# 4       400,254     10,0697             1,74                      250,203
#
#   Flotation Column 02 Air Flow  ... Flotation Column 07 Air Flow  \
# ...

# %%
data.shape
# Out:
# (737453, 24)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737453 entries, 0 to 737452
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   date                          737453 non-null  object
#  1   % Iron Feed                   737453 non-null  object
#  2   % Silica Feed                 737453 non-null  object
#  3   Starch Flow                   737453 non-null  object
#  4   Amina Flow                    737453 non-null  object
#  5   Ore Pulp Flow                 737453 non-null  object
#  6   Ore Pulp pH                   737453 non-null  object
#  7   Ore Pulp Density              737453 non-null  object
#  8   Flotation Column 01 Air Flow  737453 non-null  object
#  9   Flotation Column 02 Air Flow  737453 non-null  object
#  10  Flotation Column 03 Air Flow  737453 non-null  object
#  11  Flotation Column 04 Air Flow  737453 non-null  object
# ...

# %%
data.describe()
# Out:
#                        date % Iron Feed % Silica Feed Starch Flow Amina Flow  \
# count                737453      737453        737453      737453     737453
# unique                 4097         278           293      409317     319416
# top     2017-06-16 15:00:00       64,03          6,26      2562,5    534,668
# freq                    180      142560        142560         690        959
#
#        Ore Pulp Flow Ore Pulp pH Ore Pulp Density  \
# count         737453      737453           737453
# unique        180189      131143           105805
# top          402,246     10,0591             1,75
# freq            1735        1509             3214
#
#        Flotation Column 01 Air Flow Flotation Column 02 Air Flow  ...  \
# count                        737453                       737453  ...
# unique                        43675                        80442  ...
# top                         299,927                      255,322  ...
# ...

# %%
data.isna()
# Out:
#          date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0       False        False          False        False       False
# 1       False        False          False        False       False
# 2       False        False          False        False       False
# 3       False        False          False        False       False
# 4       False        False          False        False       False
# ...       ...          ...            ...          ...         ...
# 737448  False        False          False        False       False
# 737449  False        False          False        False       False
# 737450  False        False          False        False       False
# 737451  False        False          False        False       False
# 737452  False        False          False        False       False
#
#         Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# 0               False        False             False
# ...

# %%
data = data.replace(',','.', regex=True)

# %%
data.head()
# Out:
#                   date % Iron Feed % Silica Feed Starch Flow Amina Flow  \
# 0  2017-03-10 01:00:00        55.2         16.98     3019.53    557.434
# 1  2017-03-10 01:00:00        55.2         16.98     3024.41    563.965
# 2  2017-03-10 01:00:00        55.2         16.98     3043.46    568.054
# 3  2017-03-10 01:00:00        55.2         16.98     3047.36    568.665
# 4  2017-03-10 01:00:00        55.2         16.98     3033.69    558.167
#
#   Ore Pulp Flow Ore Pulp pH Ore Pulp Density Flotation Column 01 Air Flow  \
# 0       395.713     10.0664             1.74                      249.214
# 1       397.383     10.0672             1.74                      249.719
# 2       399.668      10.068             1.74                      249.741
# 3       397.939     10.0689             1.74                      249.917
# 4       400.254     10.0697             1.74                      250.203
#
#   Flotation Column 02 Air Flow  ... Flotation Column 07 Air Flow  \
# ...

# %%
duplicates_count = data['date'].duplicated().sum()

# %%
duplicates_count
# Out:
# 733356

# %%
window_size_of_1hour=data['date'].drop_duplicates()

# %%
window_size_of_1hour
# Out:
# 0         2017-03-10 01:00:00
# 174       2017-03-10 02:00:00
# 354       2017-03-10 03:00:00
# 534       2017-03-10 04:00:00
# 714       2017-03-10 05:00:00
#                  ...
# 736553    2017-09-09 19:00:00
# 736733    2017-09-09 20:00:00
# 736913    2017-09-09 21:00:00
# 737093    2017-09-09 22:00:00
# 737273    2017-09-09 23:00:00
# Name: date, Length: 4097, dtype: object

# %%
df_windowsize=pd.DataFrame(window_size_of_1hour)

# %%
df_windowsize
# Out:
#                        date
# 0       2017-03-10 01:00:00
# 174     2017-03-10 02:00:00
# 354     2017-03-10 03:00:00
# 534     2017-03-10 04:00:00
# 714     2017-03-10 05:00:00
# ...                     ...
# 736553  2017-09-09 19:00:00
# 736733  2017-09-09 20:00:00
# 736913  2017-09-09 21:00:00
# 737093  2017-09-09 22:00:00
# 737273  2017-09-09 23:00:00
#
# [4097 rows x 1 columns]

# %%
index_list = df_windowsize.index.values.tolist()

# %%
index_list
# Out:
# [0,
#  174,
#  354,
#  534,
#  714,
#  894,
#  1074,
#  1254,
#  1434,
#  1614,
#  1794,
#  1974,
#  2154,
#  2334,
#  2514,
#  2694,
#  2874,
#  3054,
#  3234,
#  3414,
#  3594,
#  3774,
#  3954,
#  4134,
#  4314,
#  4494,
#  4674,
#  4854,
#  5034,
#  5214,
#  5394,
#  5574,
#  5754,
#  5934,
#  6114,
#  6294,
#  6474,
#  6654,
#  6834,
#  7014,
#  7194,
#  7374,
#  7554,
#  7734,
#  7914,
#  8094,
#  8274,
#  8454,
#  8634,
#  8814,
#  8994,
#  9174,
#  9354,
#  9534,
#  9714,
#  9894,
#  10074,
#  10254,
#  10434,
#  10614,
#  10794,
#  10974,
#  11154,
#  11334,
#  11514,
#  11694,
#  11874,
#  12054,
#  12234,
#  12414,
#  12594,
#  12774,
#  12954,
#  13134,
#  13314,
#  13494,
#  13674,
#  13854,
#  14034,
#  14214,
#  14394,
#  14574,
#  14754,
#  14934,
#  15114,
#  15294,
#  15474,
#  15654,
#  15834,
#  16014,
#  16194,
#  16374,
#  16554,
#  16734,
#  16914,
#  17094,
#  17274,
#  17454,
#  17634,
#  17814,
#  17994,
#  18174,
#  18354,
#  18534,
#  18714,
#  18894,
# ...

# %%
data_fnl=data.query('index in @index_list')

# %%
data_fnl
# Out:
#                        date % Iron Feed % Silica Feed Starch Flow Amina Flow  \
# 0       2017-03-10 01:00:00        55.2         16.98     3019.53    557.434
# 174     2017-03-10 02:00:00        55.2         16.98     3170.41    539.673
# 354     2017-03-10 03:00:00        55.2         16.98     3365.65    573.517
# 534     2017-03-10 04:00:00        55.2         16.98     2693.75    592.133
# 714     2017-03-10 05:00:00        55.2         16.98    2352.216    601.807
# ...                     ...         ...           ...         ...        ...
# 736553  2017-09-09 19:00:00       49.75          23.2     2888.06     494.99
# 736733  2017-09-09 20:00:00       49.75          23.2     4218.57    492.027
# 736913  2017-09-09 21:00:00       49.75          23.2      3159.1    520.986
# 737093  2017-09-09 22:00:00       49.75          23.2     3348.19    511.961
# 737273  2017-09-09 23:00:00       49.75          23.2     2983.08    461.285
#
# ...

# %%
data_fnl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4097 entries, 0 to 737273
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   date                          4097 non-null   object
#  1   % Iron Feed                   4097 non-null   object
#  2   % Silica Feed                 4097 non-null   object
#  3   Starch Flow                   4097 non-null   object
#  4   Amina Flow                    4097 non-null   object
#  5   Ore Pulp Flow                 4097 non-null   object
#  6   Ore Pulp pH                   4097 non-null   object
#  7   Ore Pulp Density              4097 non-null   object
#  8   Flotation Column 01 Air Flow  4097 non-null   object
#  9   Flotation Column 02 Air Flow  4097 non-null   object
#  10  Flotation Column 03 Air Flow  4097 non-null   object
#  11  Flotation Column 04 Air Flow  4097 non-null   object
# ...

# %%
data_fnl2=data_fnl.drop('date',axis=1)

# %%
data_fnl2
# Out:
#        % Iron Feed % Silica Feed Starch Flow Amina Flow   Ore Pulp Flow  \
# 0             55.2         16.98     3019.53    557.434         395.713
# 174           55.2         16.98     3170.41    539.673         399.697
# 354           55.2         16.98     3365.65    573.517         399.023
# 534           55.2         16.98     2693.75    592.133         409.204
# 714           55.2         16.98    2352.216    601.807         398.145
# ...            ...           ...         ...        ...             ...
# 736553       49.75          23.2     2888.06     494.99         376.468
# 736733       49.75          23.2     4218.57    492.027          378.63
# 736913       49.75          23.2      3159.1    520.986  381.4686666667
# 737093       49.75          23.2     3348.19    511.961         379.684
# 737273       49.75          23.2     2983.08    461.285         378.691
#
#        Ore Pulp pH Ore Pulp Density Flotation Column 01 Air Flow  \
# ...

# %%
data_fnl2=data_fnl2.astype(float)

# %%
data_fnl2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4097 entries, 0 to 737273
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   % Iron Feed                   4097 non-null   float64
#  1   % Silica Feed                 4097 non-null   float64
#  2   Starch Flow                   4097 non-null   float64
#  3   Amina Flow                    4097 non-null   float64
#  4   Ore Pulp Flow                 4097 non-null   float64
#  5   Ore Pulp pH                   4097 non-null   float64
#  6   Ore Pulp Density              4097 non-null   float64
#  7   Flotation Column 01 Air Flow  4097 non-null   float64
#  8   Flotation Column 02 Air Flow  4097 non-null   float64
#  9   Flotation Column 03 Air Flow  4097 non-null   float64
#  10  Flotation Column 04 Air Flow  4097 non-null   float64
#  11  Flotation Column 05 Air Flow  4097 non-null   float64
# ...

# %%
data_fnl2.corr()
# Out:
#                               % Iron Feed  % Silica Feed  Starch Flow  \
# % Iron Feed                      1.000000      -0.971833     0.010829
# % Silica Feed                   -0.971833       1.000000     0.004561
# Starch Flow                      0.010829       0.004561     1.000000
# Amina Flow                      -0.086668       0.078412     0.263796
# Ore Pulp Flow                    0.173879      -0.162403     0.046497
# Ore Pulp pH                      0.003863       0.011527     0.257577
# Ore Pulp Density                -0.128495       0.107540     0.228972
# Flotation Column 01 Air Flow    -0.064857       0.094566     0.174785
# Flotation Column 02 Air Flow    -0.176825       0.189771     0.175662
# Flotation Column 03 Air Flow    -0.062733       0.085386     0.165230
# Flotation Column 04 Air Flow    -0.135588       0.158653     0.080268
# Flotation Column 05 Air Flow     0.114150      -0.124311    -0.091961
# ...

# %%
#There is -0.801984 correlation factor between %silica concentrate and %iron concentrate

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data_fnl2['% Iron Concentrate'], data_fnl2['% Silica Concentrate'], marker='o')
plt.xlabel('% Iron Concentrate')
plt.ylabel('% Silica Concentrate')
plt.title('Graph between % Iron Concentrate and % Silica Concentrate')
plt.grid(True)
plt.show()

# %%
plt.plot(data_fnl2['% Iron Concentrate'], color='blue', label='% Iron Concentrate')
plt.plot(data_fnl2['% Silica Concentrate'], color='red', label='% Silica Concentrate')
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Values of % Iron Concentrate and % Silica Concentrate')
plt.legend()
plt.grid(True)
plt.show()

# %%
#we have to do multivariate timeseries forecasting between %iron concentrate and %silica concentrate as they are highly corelated and also our variable of interest

# %%
data_needed=data_fnl[['% Iron Concentrate','% Silica Concentrate']]

# %%
data_needed
# Out:
#        % Iron Concentrate % Silica Concentrate
# 0                   66.91                 1.31
# 174                 67.06                 1.11
# 354                 66.97                 1.27
# 534                 66.75                 1.36
# 714                 66.63                 1.34
# ...                   ...                  ...
# 736553              65.05                 1.65
# 736733              64.83                 1.71
# 736913              64.29                  1.8
# 737093              64.25                 1.96
# 737273              64.27                 1.71
#
# [4097 rows x 2 columns]

# %%
data_needed.isna().sum()
# Out:
# % Iron Concentrate      0
# % Silica Concentrate    0
# dtype: int64

# %%
data_needed.value_counts()
# Out:
# % Iron Concentrate  % Silica Concentrate
# 65.44               2.08                    73
# 64.03               3.11                    39
# 65.26               1.19                    28
# 62.87               5.03                    19
# 64.99               2.4                     19
#                                             ..
# 64.69               2.34                     1
#                     2.92                     1
#                     3.02                     1
#                     3.81                     1
# 68.01               1.38                     1
# Length: 3596, dtype: int64

# %%
data_needed_float=data_needed.astype(float)

# %%
data_needed_float.reset_index(drop=True, inplace=True)

# %%
data_needed_float= data_needed_float.reindex(np.arange(4097))

# %%
data_needed_float
# Out:
#       % Iron Concentrate  % Silica Concentrate
# 0                  66.91                  1.31
# 1                  67.06                  1.11
# 2                  66.97                  1.27
# 3                  66.75                  1.36
# 4                  66.63                  1.34
# ...                  ...                   ...
# 4092               65.05                  1.65
# 4093               64.83                  1.71
# 4094               64.29                  1.80
# 4095               64.25                  1.96
# 4096               64.27                  1.71
#
# [4097 rows x 2 columns]

# %%
#As it is timeseries based forecasting we will be using first 3000 datapoints for training and next 1097 for testing
train_data = np.array(data_needed.iloc[:3000])
test_data = np.array(data_needed.iloc[3000:])

# %%
#We will do min-max scaler for data

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
scaled_train=scaler.fit_transform(train_data)

# %%
scaled_test=scaler.transform(test_data)

# %%
scaled_train
# Out:
# array([[0.81543624, 0.11392405],
#        [0.84060403, 0.07172996],
#        [0.82550336, 0.10548523],
#        ...,
#        [0.39765101, 0.29113924],
#        [0.60402685, 0.14135021],
#        [0.49161074, 0.29324895]])

# %%
scaled_test
# Out:
# array([[0.62248322, 0.19620253],
#        [0.6090604 , 0.20042194],
#        [0.63926174, 0.22995781],
#        ...,
#        [0.37583893, 0.21729958],
#        [0.36912752, 0.25105485],
#        [0.37248322, 0.19831224]])

# %% [markdown]
# Time Series Analysis

# %%
#ADF test – Test for stationarity
from statsmodels.tsa.stattools import adfuller
p_value_iron=adfuller(data_needed['% Iron Concentrate'])

# %%
p_value_iron
# Out:
# (-8.477453430097842,
#  1.422680531020375e-13,
#  24,
#  4072,
#  {'1%': -3.431956931996359,
#   '5%': -2.862250054567455,
#   '10%': -2.567147969015964},
#  8923.085650066905)

# %% [markdown]
# Here p_value is 1.422680531020375e-13 which accepts the null hypothesis about data is non_stationary for %iron silicate

# %%
p_value_silica=adfuller(data_needed['% Silica Concentrate'])

# %%
p_value_silica
# Out:
# (-8.191372327015637,
#  7.651787327344752e-13,
#  24,
#  4072,
#  {'1%': -3.431956931996359,
#   '5%': -2.862250054567455,
#   '10%': -2.567147969015964},
#  8667.168689786253)

# %% [markdown]
# Here p_value is 7.651787327344752e-13 which accepts the null hypothesis about data is non_stationary for %silica silicate

# %%
#Autoregresssive Model 
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data_needed['% Iron Concentrate'], lags=30) 
plt.title('Autocorrelation Function (ACF)')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.grid(True)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(data_needed['% Iron Concentrate'], lags=30)  # Plot PACF up to 30 lags
plt.title('Partial Autocorrelation Function (PACF)')
plt.xlabel('Lag')
plt.ylabel('Partial Autocorrelation')
plt.grid(True)
plt.show()

# %% [markdown]
# p=3

# %%
plot_acf(data_needed['% Silica Concentrate'], lags=30) 
plt.title('Autocorrelation Function (ACF)')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.grid(True)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(data_needed['% Silica Concentrate'], lags=30)  # Plot PACF up to 30 lags
plt.title('Partial Autocorrelation Function (PACF)')
plt.xlabel('Lag')
plt.ylabel('Partial Autocorrelation')
plt.grid(True)
plt.show()

# %% [markdown]
# p=3

# %%
from statsmodels.tsa.arima.model import ARIMA
model_AR2_IRON = ARIMA(np.array(data_needed_float['% Iron Concentrate']), order=(3, 0, 0))

# %%
fit_modelAR2_IRON = model_AR2_IRON.fit()

# %%
fit_modelAR2_IRON.summary
# Out:
# <bound method SARIMAXResults.summary of <statsmodels.tsa.arima.model.ARIMAResults object at 0x0000026E65DFCB10>>

# %%
predictions_AR2_IRON = fit_modelAR2_IRON.predict()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data_needed_float['% Iron Concentrate'], label='Original')
plt.plot(predictions_AR2_IRON, color='red', label='Predicted')
plt.title('Original vs Predicted Values (AR Model)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA
model_AR2_SILICA = ARIMA(np.array(data_needed_float['% Silica Concentrate']), order=(3, 0, 0))

# %%
fit_modelAR2_SILICA = model_AR2_SILICA.fit()

# %%
predictions_AR2_SILICA = fit_modelAR2_SILICA.predict()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data_needed_float['% Silica Concentrate'], label='Original')
plt.plot(predictions_AR2_SILICA, color='red', label='Predicted')
plt.title('Original vs Predicted Values (AR Model)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
R2SCORE_IRON_AR2=r2_score(data_needed_float['% Iron Concentrate'],predictions_AR2_IRON)

# %%
R2SCORE_IRON_AR2
# Out:
# 0.5818659275036989

# %%
R2SCORE_SILICA_AR2=r2_score(data_needed_float['% Silica Concentrate'],predictions_AR2_SILICA )

# %%
R2SCORE_SILICA_AR2
# Out:
# 0.6125459427795237

# %% [markdown]
# r2_score is not satisafactory

# %% [markdown]
# RNN Architecture

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, SimpleRNN
# Out:
# WARNING:tensorflow:From C:\Users\dell\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
 
n_input = 6
n_features = 2
generator = TimeseriesGenerator(data=scaled_train,
                                targets=scaled_train,
                                length=n_input,
                                batch_size=128)

# %%
RNN_model=Sequential()
RNN_model.add(SimpleRNN(30, input_shape=(6, 2), activation='relu', return_sequences=True))
RNN_model.add(SimpleRNN(30, activation='relu', return_sequences=True))
RNN_model.add(SimpleRNN(30, activation='relu', return_sequences=False))
RNN_model.add(Dense(2, activation='relu'))
# Out:
# WARNING:tensorflow:From C:\Users\dell\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
RNN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  simple_rnn (SimpleRNN)      (None, 6, 30)             990
#
#  simple_rnn_1 (SimpleRNN)    (None, 6, 30)             1830
#
#  simple_rnn_2 (SimpleRNN)    (None, 30)                1830
#
#  dense (Dense)               (None, 2)                 62
#
# ...
# Total params: 4712 (18.41 KB)
# Trainable params: 4712 (18.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
RNN_model.compile(loss='mean_squared_error',optimizer='Adam')
# Out:
# WARNING:tensorflow:From C:\Users\dell\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
RNN_model_history=RNN_model.fit_generator(generator,epochs=50)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_9804\585287975.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   RNN_model_history=RNN_model.fit_generator(generator,epochs=50)
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\dell\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 24/24 [==============================] - 4s 6ms/step - loss: 0.0662
# Epoch 2/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0281
# Epoch 3/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0234
# Epoch 4/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0220
# Epoch 5/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0208
# Epoch 6/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0200
# Epoch 7/50
# ...

# %%
import matplotlib.pyplot as plt




plt.plot(RNN_model_history.history['loss'])
plt.title('Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
test_generator=TimeseriesGenerator(data=scaled_test,
                                targets=scaled_test,
                                length=n_input,batch_size=128
                                )

# %%
predictions=RNN_model.predict(test_generator)
# Out:
# 9/9 [==============================] - 1s 4ms/step

# %%
len(predictions)
# Out:
# 1091

# %%
len(scaled_test)
# Out:
# 1097

# %%
r2score_RNNmodel=r2_score(scaled_test[6:1097],predictions)

# %%
scaled_test
# Out:
# array([[0.62248322, 0.19620253],
#        [0.6090604 , 0.20042194],
#        [0.63926174, 0.22995781],
#        ...,
#        [0.37583893, 0.21729958],
#        [0.36912752, 0.25105485],
#        [0.37248322, 0.19831224]])

# %%
predictions
# Out:
# array([[0.5975033 , 0.21908689],
#        [0.5911941 , 0.20593485],
#        [0.65749323, 0.13219035],
#        ...,
#        [0.50639856, 0.22769341],
#        [0.42863014, 0.25224918],
#        [0.4089568 , 0.267377  ]], dtype=float32)

# %%
r2score_RNNmodel
# Out:
# 0.5989132270140819

# %%
df1=pd.DataFrame(scaled_test)

# %%
df1
# Out:
#              0         1
# 0     0.622483  0.196203
# 1     0.609060  0.200422
# 2     0.639262  0.229958
# 3     0.573826  0.215190
# 4     0.672819  0.160338
# ...        ...       ...
# 1092  0.503356  0.185654
# 1093  0.466443  0.198312
# 1094  0.375839  0.217300
# 1095  0.369128  0.251055
# 1096  0.372483  0.198312
#
# [1097 rows x 2 columns]

# %%
df2=pd.DataFrame(predictions)

# %%
df2
# Out:
#              0         1
# 0     0.597503  0.219087
# 1     0.591194  0.205935
# 2     0.657493  0.132190
# 3     0.664721  0.123447
# 4     0.502417  0.408021
# ...        ...       ...
# 1086  0.465711  0.252793
# 1087  0.477371  0.211485
# 1088  0.506399  0.227693
# 1089  0.428630  0.252249
# 1090  0.408957  0.267377
#
# [1091 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(df1[0], label='Original')
plt.plot(df2[0], color='red', label='Predicted')
plt.title('Original vs Predicted Values (RNN ARCHITECTURE)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df1[1], label='Original')
plt.plot(df2[1], color='red', label='Predicted')
plt.title('Original vs Predicted Values (RNN Architecture)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Hyperparameteric tunning of RNN architecture

# %%
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
from pickle import dump,load
import warnings
warnings.simplefilter("ignore", UserWarning)
from tensorflow.keras.models import save_model
from tensorflow.keras.models import model_from_json
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_9804\1566286911.py:1: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch

# %%
# Extracting X_train and y_train
X_train = generator[0][0]  # Accessing the first batch of input sequences
y_train = generator[0][1]  # Accessing the corresponding targets for the first batch

# If you have multiple batches, you can concatenate them
for i in range(1, len(generator)):
    X_batch, y_batch = generator[i]
    X_train = np.concatenate((X_train, X_batch), axis=0)
    y_train = np.concatenate((y_train, y_batch), axis=0)

# %%
# Extracting X_train and y_train
X_test = test_generator[0][0]  # Accessing the first batch of input sequences
y_test = test_generator[0][1]  # Accessing the corresponding targets for the first batch

# If you have multiple batches, you can concatenate them
for i in range(1, len(test_generator)):
    X_batch, y_batch = test_generator[i]
    X_test = np.concatenate((X_test, X_batch), axis=0)
    y_test = np.concatenate((y_test, y_batch), axis=0)

# %%
def build_model(hp):
    model = Sequential()
    model.add(SimpleRNN(hp.Int('input_unit',min_value=32,max_value=512,step=32),return_sequences=True, input_shape=(X_train.shape[1],X_train.shape[2])))
    for i in range(hp.Int('n_layers', 1, 4)):
        model.add(SimpleRNN(hp.Int(f'rnn_{i}_units',min_value=32,max_value=512,step=32),return_sequences=True))
    model.add(SimpleRNN(hp.Int('input_unit',min_value=32,max_value=512,step=32),return_sequences=False))
    model.add(Dense(2, activation='relu'))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=[keras.metrics.MeanAbsoluteError()])
    return model

# %%
import keras_tuner 

tuner= RandomSearch(
        build_model,
        objective=keras_tuner.Objective("val_mean_absolute_error", direction="min"),
        max_trials=2,
        executions_per_trial=1
        )
# Out:
# Reloading Tuner from .\untitled_project\tuner0.json

# %%
tuner.search(
        x=X_train,
        y=y_train,
        epochs=100,
        validation_data=(X_test,y_test),
        batch_size=32
    
)

# %%
best_model = tuner.get_best_models(num_models=1)[0]

# %%
best_model

# %%
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  simple_rnn (SimpleRNN)      (None, 6, 416)            174304
#
#  simple_rnn_1 (SimpleRNN)    (None, 6, 32)             14368
#
#  simple_rnn_2 (SimpleRNN)    (None, 6, 32)             2080
#
#  simple_rnn_3 (SimpleRNN)    (None, 6, 32)             2080
#
#  simple_rnn_4 (SimpleRNN)    (None, 6, 32)             2080
#
#  simple_rnn_5 (SimpleRNN)    (None, 416)               186784
#
#  dense (Dense)               (None, 2)                 834
#
# ...
# Total params: 382530 (1.46 MB)
# Trainable params: 382530 (1.46 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#LSTM ARchitecture 

#It is based on the following research paper-Long short-term memory-based grade monitoring in froth flotation using a froth video sequence

# %%
LSTM_model2=Sequential()
LSTM_model2.add(LSTM(30, input_shape=(6, 2), activation='relu', return_sequences=True))
LSTM_model2.add(LSTM(30, activation='relu', return_sequences=True))
LSTM_model2.add(LSTM(30, activation='relu', return_sequences=True))
LSTM_model2.add(LSTM(30, activation='relu', return_sequences=False))
LSTM_model2.add(Dense(2, activation='relu'))

# %%
LSTM_model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_7 (LSTM)               (None, 6, 30)             3960
#
#  lstm_8 (LSTM)               (None, 6, 30)             7320
#
#  lstm_9 (LSTM)               (None, 6, 30)             7320
#
#  lstm_10 (LSTM)              (None, 30)                7320
#
#  dense_3 (Dense)             (None, 2)                 62
#
# ...
# Total params: 25982 (101.49 KB)
# Trainable params: 25982 (101.49 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
LSTM_model2.compile(loss='mean_squared_error',optimizer='Adam')

# %%
LSTM_model2_history=LSTM_model2.fit_generator(generator,epochs=50)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 6s 13ms/step - loss: 0.2110
# Epoch 2/50
# 24/24 [==============================] - 1s 24ms/step - loss: 0.1045
# Epoch 3/50
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0494
# Epoch 4/50
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0457
# Epoch 5/50
# 24/24 [==============================] - 1s 16ms/step - loss: 0.0447
# Epoch 6/50
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0447
# Epoch 7/50
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0445
# Epoch 8/50
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0444
# Epoch 9/50
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0443
# Epoch 10/50
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0443
# Epoch 11/50
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0439
# Epoch 12/50
# ...

# %%
plt.plot(LSTM_model2_history.history['loss'])
plt.title('Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
predictions_LSTM=LSTM_model2.predict(test_generator)
# Out:
# 9/9 [==============================] - 0s 6ms/step

# %%
r2score_LSTMmodel2=r2_score(scaled_test[6:1097],predictions_LSTM)

# %%
r2score_LSTMmodel
# Out:
# 0.5950478735138195

# %%
predictions_LSTM
# Out:
# array([[0.61824167, 0.20786127],
#        [0.61039984, 0.20793912],
#        [0.67835116, 0.14812101],
#        ...,
#        [0.47283053, 0.23931241],
#        [0.47826838, 0.2656986 ],
#        [0.46019524, 0.28696647]], dtype=float32)

# %%
df2=pd.DataFrame(predictions_LSTM)

# %%
plt.figure(figsize=(10, 6))
plt.plot(df1[0], label='Original')
plt.plot(df2[0], color='red', label='Predicted')
plt.title('Original vs Predicted Values (LSTM ARCHITECTURE)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df1[1], label='Original')
plt.plot(df2[1], color='red', label='Predicted')
plt.title('Original vs Predicted Values (LSTM ARCHITECTURE)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Transformer based architecture

# %%
import tensorflow as tf
from keras import layers
import time
import timeit
from sklearn.metrics import mean_absolute_percentage_error

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0, epsilon=1e-6, attention_axes=None, kernel_size=1):
  """
  Creates a single transformer block.
  """
  x = layers.LayerNormalization(epsilon=epsilon)(inputs)
  x = layers.MultiHeadAttention(
      key_dim=head_size, num_heads=num_heads, dropout=dropout,
      attention_axes=attention_axes
      )(x, x)
  x = layers.Dropout(dropout)(x)
  res = x + inputs

    # Feed Forward Part
  x = layers.LayerNormalization(epsilon=epsilon)(res)
  x = layers.Conv1D(filters=ff_dim, kernel_size=kernel_size, activation="relu")(x)
  x = layers.Dropout(dropout)(x)
  x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=kernel_size)(x)
  return x + res

def build_transfromer(head_size, num_heads, ff_dim, num_trans_blocks, mlp_units, dropout=0, mlp_dropout=0, attention_axes=None, epsilon=1e-6, kernel_size=1):
  """
  Creates final model by building many transformer blocks.
  """
  n_timesteps, n_features, n_outputs = 6, 2, 2
  inputs = tf.keras.Input(shape=(n_timesteps, n_features))
  x = inputs
  for _ in range(num_trans_blocks):
    x = transformer_encoder(x, head_size=head_size, num_heads=num_heads, ff_dim=ff_dim, dropout=dropout, attention_axes=attention_axes, kernel_size=kernel_size, epsilon=epsilon)

  x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
  for dim in mlp_units:
    x = layers.Dense(dim, activation="relu")(x)
    x = layers.Dropout(mlp_dropout)(x)

  outputs = layers.Dense(n_outputs)(x)
  return tf.keras.Model(inputs, outputs)

# %%
transformer = build_transfromer(head_size=128, num_heads=4, ff_dim=2, num_trans_blocks=4, mlp_units=[256], mlp_dropout=0.10, dropout=0.10, attention_axes=1)

# %%
def fit_transformer(transformer: tf.keras.Model):
  """
  Compiles and fits our transformer.
  """
  transformer.compile(
    loss="mse",
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    metrics=["mae", 'mape'])

  callbacks = [tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)]
  start = time.time()
  hist = transformer.fit(generator, batch_size=32, epochs=100, verbose=1, callbacks=callbacks)
  print(time.time() - start)
  return hist

# %%
history_transfomer = fit_transformer(transformer)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 11s 67ms/step - loss: 0.1021 - mae: 0.2421 - mape: 76982.4219
# Epoch 2/100
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0516 - mae: 0.1786 - mape: 117379.4453
# Epoch 3/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0496 - mae: 0.1739 - mape: 138912.2969
# Epoch 4/100
# 24/24 [==============================] - 2s 62ms/step - loss: 0.0500 - mae: 0.1772 - mape: 215558.0312
# Epoch 5/100
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0451 - mae: 0.1674 - mape: 170677.4531
# Epoch 6/100
# 24/24 [==============================] - 2s 62ms/step - loss: 0.0392 - mae: 0.1534 - mape: 134390.5781
# Epoch 7/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0365 - mae: 0.1496 - mape: 147087.8594
# Epoch 8/100
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0363 - mae: 0.1483 - mape: 178364.8906
# Epoch 9/100
# ...

# %%
plt.plot(history_transfomer.history['loss'])
plt.title('Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
predictions_transformer=transformer.predict(test_generator)
# Out:
# 9/9 [==============================] - 1s 27ms/step

# %%
r2score_transformer=r2_score(scaled_test[6:1097],predictions_transformer)

# %%
predictions_transformer
# Out:
# array([[0.5624749 , 0.208504  ],
#        [0.5576968 , 0.21139829],
#        [0.5607503 , 0.20887013],
#        ...,
#        [0.46578792, 0.31164616],
#        [0.51915616, 0.23720334],
#        [0.49887013, 0.22543545]], dtype=float32)

# %%
r2score_transformer
# Out:
# 0.4456239578722745

# %%
df2=pd.DataFrame(predictions_transformer)

# %%
plt.figure(figsize=(10, 6))
plt.plot(df1[0], label='Original')
plt.plot(df2[0], color='red', label='Predicted')
plt.title('Original vs Predicted Values (Transformer ARCHITECTURE)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df1[1], label='Original')
plt.plot(df2[1], color='red', label='Predicted')
plt.title('Original vs Predicted Values (Transformer ARCHITECTURE)')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
